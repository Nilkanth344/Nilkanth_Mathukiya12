# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/customer_purchase_dataset.csv')

# %%
df.head()
# Out:
#     age  annual_income  monthly_spend  website_visits  time_on_site_minutes  \
# 0  49.0        74207.0         336.46            14.0                 31.96
# 1  64.0        68651.0         409.19            14.0                 19.40
# 2  22.0        26819.0         428.46             5.0                 20.78
# 3  18.0        20852.0         353.88             0.0                  9.22
# 4  56.0        78159.0         436.53            21.0                 26.86
#
#    past_purchases  email_engagement_score  loyalty_years  purchased
# 0             5.0                   34.41            9.9          0
# 1             4.0                   37.10            7.1          0
# 2             8.0                   35.97            3.2          0
# 3             3.0                   33.90            2.2          0
# 4             3.0                   27.74            7.9          0

# %%
df.tail()
# Out:
#        age  annual_income  monthly_spend  website_visits  \
# 1195  45.0        78168.0         382.93            18.0
# 1196  34.0        76788.0          50.53             6.0
# 1197  18.0        65081.0         456.08            37.0
# 1198  47.0        63048.0         471.79            33.0
# 1199  18.0        15000.0         490.14             0.0
#
#       time_on_site_minutes  past_purchases  email_engagement_score  \
# 1195                  8.88             4.0                   31.47
# 1196                  9.34             4.0                   35.27
# 1197                  1.00             7.0                   46.97
# 1198                 13.99             6.0                   56.48
# 1199                 21.14             9.0                   36.61
#
#       loyalty_years  purchased
# 1195           12.3          0
# 1196            5.8          1
# 1197            4.8          1
# 1198            2.2          1
# 1199            1.4          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     1200 non-null   float64
#  1   annual_income           1200 non-null   float64
#  2   monthly_spend           1200 non-null   float64
#  3   website_visits          1200 non-null   float64
#  4   time_on_site_minutes    1200 non-null   float64
#  5   past_purchases          1200 non-null   float64
#  6   email_engagement_score  1200 non-null   float64
#  7   loyalty_years           1200 non-null   float64
#  8   purchased               1200 non-null   int64
# dtypes: float64(8), int64(1)
# memory usage: 84.5 KB

# %%
df.dtypes
# Out:
# age                       float64
# annual_income             float64
# monthly_spend             float64
# website_visits            float64
# time_on_site_minutes      float64
# past_purchases            float64
# email_engagement_score    float64
# loyalty_years             float64
# purchased                   int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# age                       0
# annual_income             0
# monthly_spend             0
# website_visits            0
# time_on_site_minutes      0
# past_purchases            0
# email_engagement_score    0
# loyalty_years             0
# purchased                 0
# dtype: int64

# %%
df.describe()
# Out:
#                age  annual_income  monthly_spend  website_visits  \
# count  1200.000000    1200.000000    1200.000000     1200.000000
# mean     47.294167   59359.518333     383.301183       15.619167
# std      16.094207   25011.487348     156.728668        9.418584
# min      18.000000   15000.000000      10.000000        0.000000
# 25%      36.000000   41873.750000     321.282500        8.000000
# 50%      50.000000   60427.000000     414.480000       15.000000
# 75%      60.000000   74449.000000     489.517500       23.000000
# max      70.000000  150000.000000     744.910000       42.000000
#
#        time_on_site_minutes  past_purchases  email_engagement_score  \
# count           1200.000000     1200.000000             1200.000000
# mean              19.977958        5.036667               41.484408
# std                8.087279        3.025936               16.022558
# min                1.000000        0.000000                0.000000
# ...

# %%
for col in df.columns:
    if df[col].dtype == 'float64':
        df[col] = df[col].astype(int)

display(df.dtypes)
# Out:
# age                       int64
# annual_income             int64
# monthly_spend             int64
# website_visits            int64
# time_on_site_minutes      int64
# past_purchases            int64
# email_engagement_score    int64
# loyalty_years             int64
# purchased                 int64
# dtype: object

# %%
display(df.head())
# Out:
#    age  annual_income  monthly_spend  website_visits  time_on_site_minutes  \
# 0   49          74207            336              14                    31
# 1   64          68651            409              14                    19
# 2   22          26819            428               5                    20
# 3   18          20852            353               0                     9
# 4   56          78159            436              21                    26
#
#    past_purchases  email_engagement_score  loyalty_years  purchased
# 0               5                      34              9          0
# 1               4                      37              7          0
# 2               8                      35              3          0
# 3               3                      33              2          0
# 4               3                      27              7          0

# %%
display(df.tail())
# Out:
#       age  annual_income  monthly_spend  website_visits  time_on_site_minutes  \
# 1195   45          78168            382              18                     8
# 1196   34          76788             50               6                     9
# 1197   18          65081            456              37                     1
# 1198   47          63048            471              33                    13
# 1199   18          15000            490               0                    21
#
#       past_purchases  email_engagement_score  loyalty_years  purchased
# 1195               4                      31             12          0
# 1196               4                      35              5          1
# 1197               7                      46              4          1
# 1198               6                      56              2          1
# 1199               9                      36              1          0

# %% [markdown]
# Import Visulization Library

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Heatmap Visulization

# %%
plt.figure(figsize=(9,5))
sns.heatmap(data=df.corr(), annot=True, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# CountPlot Visulization

# %%
plt.figure(figsize=(9.6,5))
sns.countplot(x ='purchased', data = df, color='red', width=0.8)
plt.title('Total Purchase Count')
plt.show()

# %% [markdown]
# ### Distribution of Annual Income

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['annual_income'], kde=True, bins=30)
plt.title('Distribution of Annual Income')
plt.xlabel('Annual Income')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Annual Income vs. Purchased Status

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='purchased', y='annual_income', data=df)
plt.title('Annual Income by Purchase Status')
plt.xlabel('Purchased (0: No, 1: Yes)')
plt.ylabel('Annual Income')
plt.show()

# %% [markdown]
# Import Other Library

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# Feature Selection

# %%
X = df.drop('purchased', axis=1)
y = df['purchased']

# %% [markdown]
# ### Standardize the features

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)
display(X_scaled_df.head())
# Out:
#         age  annual_income  monthly_spend  website_visits  \
# 0  0.106035       0.593874      -0.299065       -0.171984
# 1  1.038436       0.371643       0.167077       -0.171984
# 2 -1.572287      -1.301565       0.288401       -1.127940
# 3 -1.820927      -1.540235      -0.190512       -1.659026
# 4  0.541155       0.751947       0.339486        0.571538
#
#    time_on_site_minutes  past_purchases  email_engagement_score  loyalty_years
# 0              1.427153       -0.012123               -0.436149       1.309875
# 1             -0.059572       -0.342737               -0.248894       0.713461
# 2              0.064322        0.979720               -0.373731      -0.479368
# 3             -1.298510       -0.673351               -0.498568      -0.777575
# 4              0.807684       -0.673351               -0.873079       0.713461

# %% [markdown]
# ### Split the data into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (960, 8)
# X_test shape: (240, 8)
# y_train shape: (960,)
# y_test shape: (240,)

# %% [markdown]
# Import SVC Models

# %%
from sklearn.svm import SVC

# %%
model = SVC(kernel='linear', C=0.1)

# %%
model.fit(X_train, y_train)
# Out:
# SVC(C=0.1, kernel='linear')

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
acc = accuracy_score(y_test,y_pred)
print(f'the accuracy is: {acc * 100:.2f}%')
# Out:
# the accuracy is: 80.83%

# %%
metrics = confusion_matrix(y_test,y_pred)
print(metrics)
# Out:
# [[112  21]
#  [ 25  82]]

# %%
report = classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       133
#            1       0.80      0.77      0.78       107
#
#     accuracy                           0.81       240
#    macro avg       0.81      0.80      0.81       240
# weighted avg       0.81      0.81      0.81       240
